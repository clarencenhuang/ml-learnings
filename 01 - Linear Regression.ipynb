# %% [markdown]
# # Linear Regression Exploration

# %% [markdown]
# ### 8-9-2018

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.arange(0, 10, 0.01)
m = 1#np.random.randint(-2, 2)
x = m * y + np.random.randn(y.shape[0])

# %%
plt.plot(y, x, '*')
